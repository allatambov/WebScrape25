# %% [markdown]
# # Web-scraping: сбор данных из баз данных и интернет-источников
#
# *Алла Тамбовцева, НИУ ВШЭ*
#
# ## Домашнее задание 3
#
# ### Формат сдачи
#
# Задание выполняется самостоятельно. При любых нетривиальных совпадениях в решениях задач все вовлечённые домашние работы будут оценены на 0 баллов. Свой ipynb-файл с решением необходимо прислать до дедлайна на почту allatambov@gmail.com.

# %% [markdown]
# ### Задача 1 (max 3 балла)
#
# На [странице](http://vote.duma.gov.ru/vote/96050) представлены результаты голосования по законопроекту. Соберите (любым образом) информацию по итогам голосования:
#
# * число и процент голосов «за»;
# * число и процент голосов «против»;
# * число и процент голосов воздержавшихся;
# * число и процент голосов не голосовавших.
#
# Информация должна быть представлена в виде датафрейма такого вида (столбцы с голосами – тип `integer`, столбцы с процентами – тип `float`):
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>for</th>
#       <th>for(%)</th>
#       <th>against</th>
#       <th>against(%)</th>
#       <th>refrain</th>
#       <th>refrain(%)</th>
#       <th>missed</th>
#       <th>missed(%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>447</td>
#       <td>99.3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0.7</td>
#     </tr>
#   </tbody>
# </table>
#
# Возможная стратегия: найти подходящие фрагменты кода и извлечь из них числа. Для практики стоит попробовать сделать это с помощью регулярных выражений (хотя без них можно обойтись), здесь явно напрашивается выделение групп.
#
# *Оценивание задачи: корректное решение – 2 балла, корректное решение с использованием регулярных выражений – 3 балла.*

# %%
url = "http://vote.duma.gov.ru/vote/96050"

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Напишите функцию, которая принимает на вход ссылку на страницу и возвращает датафрейм как в задаче выше, только с добавленным столбцом, содержащим ссылку на законопроект (положение столбца не важно, он может быть и в начале, и в конце таблицы).
#
# **Пример работы функции:**
#
# Запуск функции – название может быть любым:
#
#     my_function("http://vote.duma.gov.ru/vote/96050")
#
# Результат:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>for</th>
#       <th>for(%)</th>
#       <th>against</th>
#       <th>against(%)</th>
#       <th>refrain</th>
#       <th>refrain(%)</th>
#       <th>missed</th>
#       <th>missed(%)</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>447</td>
#       <td>99.3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0.7</td>
#       <td>http://vote.duma.gov.ru/vote/96050</td>
#     </tr>
#   </tbody>
# </table>

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (1 балл)
#
# Примените функцию из предыдущей задачи к ссылкам из списка `links` и соберите из полученных результатов датафрейм следующего вида:
#
# <img src="https://github.com/allatambov/WebScrape25/blob/main/fin.png?raw=true" width="70%"/>
#
# **Подсказка:** если у нас есть есть список датафреймов вида `[df1, df2]`, можно применить к нему [функцию](https://pandas.pydata.org/docs/reference/api/pandas.concat.html) `concat()` из `pandas` и склеить датафреймы из списка в единую таблицу.

# %%
links = ["http://vote.duma.gov.ru/vote/96050", 
         "http://vote.duma.gov.ru/vote/97000", 
         "http://vote.duma.gov.ru/vote/96500", 
         "http://vote.duma.gov.ru/vote/94800", 
         "http://vote.duma.gov.ru/vote/94809", 
         "http://vote.duma.gov.ru/vote/93809", 
         "http://vote.duma.gov.ru/vote/93824",
         "http://vote.duma.gov.ru/vote/92855",
         "http://vote.duma.gov.ru/vote/93829",
         "http://vote.duma.gov.ru/vote/95700"]

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (max 3 балла)
#
# Вернемся к ссылке `url` из первой задачи. Помимо сводной информации по голосованию на [странице](http://vote.duma.gov.ru/vote/96050) есть таблица с информацией о том, какой голос оставил каждый депутат. Таблица динамическая – ее можно листать, фильтровать и сортировать. Для извлечения полной информации из такой таблицы нужно либо использовать Selenium, чтобы открыть браузер «в режиме пользователя» и пролистать ее до конца, или найти файл, откуда данные подставляются в такую таблицу.
#
# Отдельного файла здесь нет, однако нужная информация (причем для всей таблицы, для всех букв алфавита сразу) находится в исходном коде страницы в виде JSON-строки внутри кода JavaScript.
#
# Задача:
#
# * найти подходящий фрагмент кода JavaScript;
# * извлечь из него JSON-строку, похожую на список словарей, где один словарь описывает строку в таблице с голосом одного депутата (желательно выполнять поиск с помощью регулярных выражений);
# * преобразовать строку с этим списком внутри в список словарей, а затем – в датафрейм, или сразу в датафрейм;
# * убрать лишние столбцы датафрейма.
#
# Итоговый результат (первую строку с пустым именем можно убрать):
#
# <img src="https://github.com/allatambov/WebScrape25/blob/main/votes_fin.png?raw=true" width="70%"/>
#
# **Полезный факт.** Если вы нашли подходящую JSON-строку, которая внутри выглядит как список словарей или список списков, можно не использовать модуль `json`, а сразу воспользоваться функцией `read_json()` из `pandas` для преобразования результата сразу в датафрейм. Пример кода:
#
#     text = '[{"name" : "Alla", "age" : "30"}, {"name" : "Ann", "age" : 23}]'
#     pd.read_json(text)
#
# *Оценивание задачи: корректное решение – 2 балла, корректное решение с использованием регулярных выражений – 3 балла.*

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (1 балл)
#
# Напишите функцию, которая принимает на вход ссылку на страницу и сохраняет в CSV-файл датафрейм с результатами голосования (как в задаче выше). Название CSV-файла должно представлять собой id законопроекта – указан в конце ссылки например, `96050` в ссылке `url`).
#
# **Пример работы функции:**
#
# Запуск функции – название может быть любым:
#
#     get_csv("http://vote.duma.gov.ru/vote/96050")
#
# Результат:
#
#     Файл 96050.csv в рабочей папке.
#
#
# Примените эту функцию ко всем ссылкам в списке `links` из задачи 3.

# %%
### YOUR CODE HERE ###
